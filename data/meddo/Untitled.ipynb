# %%
mkdir conll_test

# %%
test_file_path = "../meddo/meddoprof_shared_task/meddoprof_test_txt/"

# %%
import os

# %%
import shutil

# %%
file_names = os.listdir(test_file_path)

# %%
folder_name=[file_name[:-4] for file_name in file_names]

# %%
def create_folder(folder_name, dir_name,file_name):
    dir_path = os.path.join(folder_name, dir_name)
    os.mkdir(dir_path)
    shutil.copyfile(file_name, os.path.join(dir_path, dir_name+".txt"))

# %%
prefix_name = "./conll_test"
for dir_name,file_name in zip(folder_name,src_file):
    assert dir_name==file_name.split("/")[-1][:-4] == dir_name
    create_folder(prefix_name, dir_name, file_name)
    print('done')
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
src_file
# Out:
# ['../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones230.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones117.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/caso_clinico_neurologia195.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones176.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/caso_clinico_neurologia191.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/caso_clinico_psiquiatria433.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/caso_clinico_medicina_interna996.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones11.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/caso_clinico_endocrinologia202.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones192.txt',
#  '../meddo/meddoprof_shared_task/meddoprof_test_txt/casos_clinicos_profesiones221.txt',
# ...

# %%
ls
# Out:
# conll_test/             tags.txt  train/          val/
# interactive/            test/     train_bio       val_bio
# meddoprof_shared_task/  test_bio  Untitled.ipynb

# %%
cd conll_test/
# Out:
# /home/dsanyal/.pix2pix/pytorch-CycleGAN-and-pix2pix/meddoprof_sharedtask/data/meddo/conll_test

# %%
mkdir conll_meddo
